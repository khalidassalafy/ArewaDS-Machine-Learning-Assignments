# %% [markdown]
# # Visualizing Iris Dataset from Kaggle

# %% [markdown]
# ## Data Description
# The Iris dataset was used in R.A. Fisher's classic 1936 paper, The Use of Multiple Measurements in Taxonomic Problems, and can also be found on the UCI Machine Learning Repository.
#
# It includes three iris species with 50 samples each as well as some properties about each flower. One flower species is linearly separable from the other two, but the other two are not linearly separable from each other.
#
# The columns in this dataset are:
#
# Id,
# SepalLengthCm,
# SepalWidthCm,
# PetalLengthCm,
# PetalWidthCm,
# Species

# %% [markdown]
# We will use Matplotlib to visualize the distribution of the sepal length of the iris flowers using a histogram:

# %% [markdown]
# ## Reading the data

# %% [markdown]
# Let'read the data first and store it in a pandas dataframe

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset into a Pandas dataframe
iris_df = pd.read_csv("data\Iris.csv")

# %% [markdown]
# We can then look at the first few rows in the data

# %%
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ## Vsiualizing the distribution of sepal length
# Now we can visualize the distribution of the sepal length of the iris flowers using a histogram:

# %%
# Select the "SepalLengthCm" column and convert it to a NumPy array
sepal_lengths = iris_df["SepalLengthCm"].values

# Create a histogram with 10 bins
plt.hist(sepal_lengths, bins=10)

# Set the title and axis labels
plt.title("Distribution of Sepal Length")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")

# Display the plot
plt.show()

# %% [markdown]
# This code loads the Iris dataset into a Pandas dataframe and selects the "SepalLengthCm" column, which contains the sepal length of the iris flowers. It then converts this column to a NumPy array and creates a histogram of the data using Matplotlib's hist function.
#
# The bins parameter specifies the number of bins to use in the histogram. In this example, we use 10 bins. You can adjust this parameter to change the granularity of the histogram.
#
# Finally, we set the title and axis labels of the plot using the title, xlabel, and ylabel functions. We then display the plot using the show function.

# %% [markdown]
# ## Visualizing the distribution of sepal width

# %%
# Select the "SepalWidthCm" column and convert it to a NumPy array
sepal_widths = iris_df["SepalWidthCm"].values

# Create a histogram with 10 bins
plt.hist(sepal_lengths, bins=10)

# Set the title and axis labels
plt.title("Distribution of Sepal Width")
plt.xlabel("Sepal Width (cm)")
plt.ylabel("Frequency")

# Display the plot
plt.show()

# %% [markdown]
# ## Vsiualizing the distribution of petal length

# %%
# Select the "PetalWidthCm" column and convert it to a NumPy array
petal_lengths = iris_df["PetalLengthCm"].values

# Create a histogram with 10 bins
plt.hist(petal_lengths, bins=10)

# Set the title and axis labels
plt.title("Distribution of Pepal Width")
plt.xlabel("pepal Width (cm)")
plt.ylabel("Frequency")

# Display the plot
plt.show()

# %% [markdown]
# ## Visualizing the distribution of petal width

# %%
# Select the "PetalWidthCm" column and convert it to a NumPy array
petal_widths = iris_df["PetalWidthCm"].values

# Create a histogram with 10 bins
plt.hist(petal_widths, bins=10)

# Set the title and axis labels
plt.title("Distribution of Petal Width")
plt.xlabel("petal Width (cm)")
plt.ylabel("Frequency")

# Display the plot
plt.show()

# %% [markdown]
# ## Visualizing species distribution

# %%
# Select the "Species" column and convert it to a NumPy array
species = iris_df["Species"].values

# Create a histogram with 10 bins
plt.hist(species, bins=10)

# Set the title and axis labels
plt.title("Distribution of Species")
plt.xlabel("Species")
plt.ylabel("Frequency")

# Display the plot
plt.show()
