# %% [markdown]
# # Introduction to Time Series Forecasting

# %% [markdown]
# ## Exercise - Getting Started with Power Usage Data
# Let's get started creating a time series model to predict future power usage given past usage.
#
# The data in this example is taken from the GEFCom2014 forecasting competition. It consists of 3 years of hourly electricity load and temperature values between 2012 and 2014.
#
# Tao Hong, Pierre Pinson, Shu Fan, Hamidreza Zareipour, Alberto Troccoli and Rob J. Hyndman, "Probabilistic energy forecasting: Global Energy Forecasting Competition 2014 and beyond", International Journal of Forecasting, vol.32, no.3, pp 896-913, July-September, 2016.
#
# In the working folder of this lesson, open the notebook.ipynb file. Start by adding libraries that will help you load and visualize data

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from utils import load_data
# %matplotlib inline

# %% [markdown]
# Note, you are using the files from the included common folder which set up your environment and handle downloading the data.
#
# Next, examine the data as a dataframe calling load_data() and head():

# %%
data = pd.read_csv ('/content/drive/MyDrive/7-TimeSeries/data/energy.csv')
data.head()
# Out:
#              timestamp    load       temp
# 0  2012-01-01 00:00:00  2698.0  32.000000
# 1  2012-01-01 01:00:00  2558.0  32.666667
# 2  2012-01-01 02:00:00  2444.0  30.000000
# 3  2012-01-01 03:00:00  2402.0  31.000000
# 4  2012-01-01 04:00:00  2403.0  32.000000

# %%
energy = data[['load']]
energy.head()
# Out:
#      load
# 0  2698.0
# 1  2558.0
# 2  2444.0
# 3  2402.0
# 4  2403.0

# %% [markdown]
# Now, plot the data calling plot():

# %%
energy.plot(y='load', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %% [markdown]
# Now, plot the first week of July 2014, by providing it as input to the energy in [from date]: [to date] pattern:

# %%
energy.loc['2014-07-01':'2014-07-07'].plot(y='load', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %% [markdown]
# A beautiful plot! Take a look at these plots and see if you can determine any of the characteristics listed above. What can we surmise by visualizing the data?
#
# In the next lesson, you will create an ARIMA model to create some forecasts.
